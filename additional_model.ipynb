# %% [markdown]
# # DS-GA 1011: More data and training: an improved baseline for Language Models as Unreliable Spatial Reasoners

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sat Nov 26 22:30:31 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %%
# connect drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/babi/
# %ls
# Out:
# /content/drive/My Drive/babi
#  all.ipynb                                               README.md
#  analysis/                                               requirements.txt
#  data.tsv                                                results/
# 'Greene setup notes.md'                                  scripts/
# 'Language Models are Unreliable Spatial Reasoners.pdf'   src/
#  plot.ipynb                                              summary/

# %%
# !python scripts/test.py microsoft/deberta-v2-xxlarge-mnli
# !python scripts/analyze.py microsoft/deberta-v2-xxlarge-mnli

# %%
# !python scripts/test.py microsoft/deberta-xlarge-mnli
# !python scripts/analyze.py microsoft/deberta-xlarge-mnli

# %%
# !python scripts/test.py allenai/unifiedqa-v2-t5-3b-1363200
# !python scripts/analyze.py allenai/unifiedqa-v2-t5-3b-1363200

# %%
# !python scripts/test.py cross-encoder/nli-deberta-v3-large
# !python scripts/analyze.py cross-encoder/nli-deberta-v3-large

# %%
# !python scripts/test.py ynie/albert-xxlarge-v2-snli_mnli_fever_anli_R1_R2_R3-nli
# !python scripts/analyze.py ynie/albert-xxlarge-v2-snli_mnli_fever_anli_R1_R2_R3-nli

# %%
# !python scripts/test.py t5-3b
# !python scripts/analyze.py t5-3b

# %%
# !python scripts/test.py ada
# !python scripts/analyze.py ada

# %%
# !python scripts/test.py babbage
# !python scripts/analyze.py babbage

# %%
# !python scripts/test.py curie
# !python scripts/analyze.py curie

# %%
# !python scripts/test.py davinci
# !python scripts/analyze.py davinci

# %%
# !python scripts/test.py Joelzhang/deberta-v3-large-snli_mnli_fever_anli_R1_R2_R3-nli
# !python scripts/analyze.py Joelzhang/deberta-v3-large-snli_mnli_fever_anli_R1_R2_R3-nli
